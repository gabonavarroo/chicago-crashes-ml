# %%
pip install geopandas matplotlib shapely
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/regina/Desktop/ITAM 3 sem/Bases de datos/Proyecto/traffic_crashes_hotspots.csv")

# %%
import numpy as np

plt.figure(figsize=(10, 10))

# 1) Tamaño de burbujas más moderado
sizes = 10 + gdf["total_crashes"] / 5   # ajusta el /5 si las quieres más grandes o chicas

sc = plt.scatter(
    gdf["lon_grid"],
    gdf["lat_grid"],
    s=sizes,
    c=gdf["total_crashes"],
    cmap="Reds",
    alpha=0.7
)

# 2) Hacer zoom a donde está la mayor parte de los puntos (quita outliers)
lon_min, lon_max = np.percentile(gdf["lon_grid"], [5, 95])
lat_min, lat_max = np.percentile(gdf["lat_grid"], [5, 95])

plt.xlim(lon_min, lon_max)
plt.ylim(lat_min, lat_max)

plt.colorbar(sc, label="Total de choques")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.title("Hotspots de choques por zona")

plt.show()
